# %% [markdown]
# ### 6.1 パラメータの更新

# %% [markdown]
# ### 6.1.2 SGD

# %%
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %% [markdown]
# ### 6.1.4 Momentum

# %%
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
    
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
        
        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key]
            params[key] += self.v[key]

# %% [markdown]
# ### 6.1.5 AdaGrad

# %%
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %% [markdown]
# ### 6.2.2 隠れ層のアクティベーション分布

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

x = np.random.randn(1000, 100)
node_num = 100
hidden_layer_size = 5
activations = {}

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
    
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num)
    
    z = np.dot(x, w)
    a = sigmoid(z)
    activations[i] = a

# %%
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    plt.hist(a.flatten(), 30, range=(0,1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.3.2 Batch Normalizatonの評価

# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.optimizer import SGD, Adam

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 学習データを削減
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01


def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10, 
                                    weight_init_std=weight_init_std, use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100], output_size=10,
                                weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
    
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
    
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
    
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
    
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list


# 3.グラフの描画==========
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4,4,i+1)
    plt.title("W:" + str(w))
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--", label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)

    plt.ylim(0, 1.0)
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')
    
plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.099 - 0.109
# epoch:1 | 0.1 - 0.099
# ../common/multi_layer_net_extend.py:101: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../common/multi_layer_net_extend.py:101: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# epoch:2 | 0.097 - 0.12
# epoch:3 | 0.097 - 0.129
# epoch:4 | 0.097 - 0.145
# epoch:5 | 0.097 - 0.166
# epoch:6 | 0.097 - 0.184
# epoch:7 | 0.097 - 0.211
# epoch:8 | 0.097 - 0.232
# epoch:9 | 0.097 - 0.263
# epoch:10 | 0.097 - 0.273
# epoch:11 | 0.097 - 0.288
# epoch:12 | 0.097 - 0.308
# epoch:13 | 0.097 - 0.332
# epoch:14 | 0.097 - 0.349
# epoch:15 | 0.097 - 0.367
# epoch:16 | 0.097 - 0.374
# No handles with labels found to put in legend.
# epoch:17 | 0.097 - 0.392
# epoch:18 | 0.097 - 0.407
# epoch:19 | 0.097 - 0.417
# ============== 2/16 ==============
# ../common/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# ../common/multi_layer_net_extend.py:101: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# ../common/multi_layer_net_extend.py:101: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# epoch:0 | 0.105 - 0.093
# epoch:1 | 0.097 - 0.079
# epoch:2 | 0.097 - 0.097
# epoch:3 | 0.097 - 0.124
# epoch:4 | 0.097 - 0.145
# epoch:5 | 0.097 - 0.177
# epoch:6 | 0.097 - 0.204
# epoch:7 | 0.097 - 0.22
# epoch:8 | 0.097 - 0.253
# epoch:9 | 0.097 - 0.277
# epoch:10 | 0.097 - 0.293
# epoch:11 | 0.097 - 0.322
# epoch:12 | 0.097 - 0.343
# epoch:13 | 0.097 - 0.363
# epoch:14 | 0.097 - 0.379
# epoch:15 | 0.097 - 0.395
# epoch:16 | 0.097 - 0.415
# epoch:17 | 0.097 - 0.439
# No handles with labels found to put in legend.
# epoch:18 | 0.097 - 0.456
# epoch:19 | 0.097 - 0.469
# ============== 3/16 ==============
# epoch:0 | 0.132 - 0.072
# epoch:1 | 0.438 - 0.088
# epoch:2 | 0.615 - 0.132
# epoch:3 | 0.702 - 0.172
# epoch:4 | 0.755 - 0.209
# epoch:5 | 0.783 - 0.256
# epoch:6 | 0.843 - 0.29
# epoch:7 | 0.863 - 0.341
# epoch:8 | 0.903 - 0.392
# epoch:9 | 0.913 - 0.417
# epoch:10 | 0.949 - 0.455
# epoch:11 | 0.963 - 0.491
# epoch:12 | 0.97 - 0.513
# epoch:13 | 0.975 - 0.536
# epoch:14 | 0.978 - 0.556
# epoch:15 | 0.987 - 0.587
# epoch:16 | 0.99 - 0.598
# epoch:17 | 0.996 - 0.613
# epoch:18 | 0.998 - 0.626
# No handles with labels found to put in legend.
# epoch:19 | 0.998 - 0.642
# ============== 4/16 ==============
# epoch:0 | 0.104 - 0.13
# epoch:1 | 0.257 - 0.159
# epoch:2 | 0.382 - 0.217
# epoch:3 | 0.496 - 0.29
# epoch:4 | 0.571 - 0.358
# epoch:5 | 0.615 - 0.412
# epoch:6 | 0.653 - 0.463
# epoch:7 | 0.676 - 0.496
# epoch:8 | 0.719 - 0.549
# epoch:9 | 0.726 - 0.586
# epoch:10 | 0.761 - 0.62
# epoch:11 | 0.771 - 0.641
# epoch:12 | 0.784 - 0.658
# epoch:13 | 0.812 - 0.687
# epoch:14 | 0.813 - 0.702
# epoch:15 | 0.831 - 0.718
# epoch:16 | 0.838 - 0.736
# epoch:17 | 0.832 - 0.758
# No handles with labels found to put in legend.
# epoch:18 | 0.852 - 0.773
# epoch:19 | 0.865 - 0.801
# ============== 5/16 ==============
# epoch:0 | 0.079 - 0.097
# epoch:1 | 0.091 - 0.136
# epoch:2 | 0.105 - 0.275
# epoch:3 | 0.107 - 0.377
# epoch:4 | 0.12 - 0.473
# epoch:5 | 0.131 - 0.545
# epoch:6 | 0.15 - 0.591
# epoch:7 | 0.164 - 0.638
# epoch:8 | 0.174 - 0.686
# epoch:9 | 0.184 - 0.729
# epoch:10 | 0.195 - 0.76
# epoch:11 | 0.204 - 0.781
# epoch:12 | 0.217 - 0.798
# epoch:13 | 0.226 - 0.815
# epoch:14 | 0.23 - 0.834
# epoch:15 | 0.254 - 0.839
# epoch:16 | 0.27 - 0.845
# epoch:17 | 0.271 - 0.847
# No handles with labels found to put in legend.
# epoch:18 | 0.272 - 0.859
# epoch:19 | 0.277 - 0.872
# ============== 6/16 ==============
# epoch:0 | 0.124 - 0.125
# epoch:1 | 0.129 - 0.233
# epoch:2 | 0.103 - 0.418
# epoch:3 | 0.107 - 0.518
# epoch:4 | 0.106 - 0.619
# epoch:5 | 0.105 - 0.68
# epoch:6 | 0.105 - 0.712
# epoch:7 | 0.105 - 0.748
# epoch:8 | 0.104 - 0.791
# epoch:9 | 0.104 - 0.824
# epoch:10 | 0.112 - 0.851
# epoch:11 | 0.105 - 0.862
# epoch:12 | 0.111 - 0.879
# epoch:13 | 0.105 - 0.891
# epoch:14 | 0.122 - 0.902
# epoch:15 | 0.118 - 0.915
# epoch:16 | 0.131 - 0.933
# epoch:17 | 0.118 - 0.935
# epoch:18 | 0.117 - 0.942
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.945
# ============== 7/16 ==============
# epoch:0 | 0.093 - 0.105
# epoch:1 | 0.105 - 0.284
# epoch:2 | 0.105 - 0.615
# epoch:3 | 0.117 - 0.698
# epoch:4 | 0.117 - 0.764
# epoch:5 | 0.117 - 0.808
# epoch:6 | 0.117 - 0.835
# epoch:7 | 0.117 - 0.864
# epoch:8 | 0.117 - 0.897
# epoch:9 | 0.117 - 0.912
# epoch:10 | 0.117 - 0.926
# epoch:11 | 0.117 - 0.943
# epoch:12 | 0.117 - 0.957
# epoch:13 | 0.117 - 0.959
# epoch:14 | 0.117 - 0.965
# epoch:15 | 0.117 - 0.974
# epoch:16 | 0.117 - 0.98
# No handles with labels found to put in legend.
# epoch:17 | 0.117 - 0.983
# epoch:18 | 0.117 - 0.985
# epoch:19 | 0.117 - 0.989
# ============== 8/16 ==============
# epoch:0 | 0.117 - 0.116
# epoch:1 | 0.105 - 0.409
# epoch:2 | 0.105 - 0.692
# epoch:3 | 0.105 - 0.784
# epoch:4 | 0.105 - 0.837
# epoch:5 | 0.105 - 0.885
# epoch:6 | 0.117 - 0.921
# epoch:7 | 0.117 - 0.936
# epoch:8 | 0.117 - 0.96
# epoch:9 | 0.116 - 0.966
# epoch:10 | 0.116 - 0.976
# epoch:11 | 0.116 - 0.985
# epoch:12 | 0.116 - 0.988
# epoch:13 | 0.116 - 0.99
# epoch:14 | 0.116 - 0.992
# epoch:15 | 0.116 - 0.995
# epoch:16 | 0.116 - 0.995
# epoch:17 | 0.116 - 0.998
# epoch:18 | 0.116 - 0.999
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.999
# ============== 9/16 ==============
# epoch:0 | 0.099 - 0.133
# epoch:1 | 0.116 - 0.375
# epoch:2 | 0.116 - 0.715
# epoch:3 | 0.116 - 0.768
# epoch:4 | 0.116 - 0.803
# epoch:5 | 0.116 - 0.861
# epoch:6 | 0.116 - 0.919
# epoch:7 | 0.117 - 0.962
# epoch:8 | 0.116 - 0.983
# epoch:9 | 0.117 - 0.988
# epoch:10 | 0.117 - 0.991
# epoch:11 | 0.116 - 0.997
# epoch:12 | 0.116 - 0.998
# epoch:13 | 0.116 - 0.998
# epoch:14 | 0.116 - 0.999
# epoch:15 | 0.116 - 0.999
# epoch:16 | 0.116 - 0.999
# epoch:17 | 0.116 - 0.999
# epoch:18 | 0.116 - 0.999
# epoch:19 | 0.116 - 0.999
# No handles with labels found to put in legend.
# ============== 10/16 ==============
# epoch:0 | 0.116 - 0.099
# epoch:1 | 0.116 - 0.615
# epoch:2 | 0.116 - 0.758
# epoch:3 | 0.116 - 0.77
# epoch:4 | 0.116 - 0.901
# epoch:5 | 0.116 - 0.924
# epoch:6 | 0.116 - 0.962
# epoch:7 | 0.116 - 0.958
# epoch:8 | 0.116 - 0.983
# epoch:9 | 0.116 - 0.989
# epoch:10 | 0.116 - 0.984
# epoch:11 | 0.116 - 0.988
# epoch:12 | 0.117 - 0.996
# epoch:13 | 0.117 - 0.993
# epoch:14 | 0.116 - 0.994
# epoch:15 | 0.116 - 0.997
# epoch:16 | 0.116 - 0.999
# epoch:17 | 0.116 - 0.999
# epoch:18 | 0.116 - 0.999
# epoch:19 | 0.116 - 0.998
# No handles with labels found to put in legend.
# ============== 11/16 ==============
# epoch:0 | 0.092 - 0.171
# epoch:1 | 0.117 - 0.604
# epoch:2 | 0.116 - 0.78
# epoch:3 | 0.116 - 0.84
# epoch:4 | 0.117 - 0.864
# epoch:5 | 0.117 - 0.887
# epoch:6 | 0.117 - 0.936
# epoch:7 | 0.117 - 0.971
# epoch:8 | 0.117 - 0.985
# epoch:9 | 0.117 - 0.972
# epoch:10 | 0.117 - 0.983
# epoch:11 | 0.117 - 0.989
# epoch:12 | 0.117 - 0.952
# epoch:13 | 0.117 - 0.988
# epoch:14 | 0.116 - 0.993
# epoch:15 | 0.116 - 0.993
# epoch:16 | 0.116 - 0.979
# epoch:17 | 0.117 - 0.995
# epoch:18 | 0.117 - 0.989
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.995
# ============== 12/16 ==============
# epoch:0 | 0.117 - 0.121
# epoch:1 | 0.117 - 0.488
# epoch:2 | 0.117 - 0.6
# epoch:3 | 0.117 - 0.622
# epoch:4 | 0.117 - 0.723
# epoch:5 | 0.117 - 0.754
# epoch:6 | 0.117 - 0.769
# epoch:7 | 0.117 - 0.776
# epoch:8 | 0.117 - 0.791
# epoch:9 | 0.117 - 0.788
# epoch:10 | 0.117 - 0.793
# epoch:11 | 0.117 - 0.796
# epoch:12 | 0.117 - 0.797
# epoch:13 | 0.117 - 0.83
# epoch:14 | 0.117 - 0.877
# epoch:15 | 0.117 - 0.88
# epoch:16 | 0.117 - 0.779
# epoch:17 | 0.117 - 0.898
# epoch:18 | 0.117 - 0.905
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.902
# ============== 13/16 ==============
# epoch:0 | 0.1 - 0.208
# epoch:1 | 0.117 - 0.525
# epoch:2 | 0.116 - 0.558
# epoch:3 | 0.117 - 0.622
# epoch:4 | 0.117 - 0.711
# epoch:5 | 0.116 - 0.762
# epoch:6 | 0.117 - 0.744
# epoch:7 | 0.117 - 0.752
# epoch:8 | 0.116 - 0.786
# epoch:9 | 0.117 - 0.779
# epoch:10 | 0.117 - 0.793
# epoch:11 | 0.117 - 0.778
# epoch:12 | 0.117 - 0.793
# epoch:13 | 0.117 - 0.795
# epoch:14 | 0.117 - 0.791
# epoch:15 | 0.117 - 0.798
# epoch:16 | 0.117 - 0.767
# No handles with labels found to put in legend.
# epoch:17 | 0.117 - 0.795
# epoch:18 | 0.117 - 0.799
# epoch:19 | 0.117 - 0.801
# ============== 14/16 ==============
# epoch:0 | 0.105 - 0.151
# epoch:1 | 0.116 - 0.379
# epoch:2 | 0.117 - 0.504
# epoch:3 | 0.116 - 0.505
# epoch:4 | 0.116 - 0.514
# epoch:5 | 0.116 - 0.519
# epoch:6 | 0.116 - 0.521
# epoch:7 | 0.116 - 0.567
# epoch:8 | 0.116 - 0.59
# epoch:9 | 0.116 - 0.593
# epoch:10 | 0.117 - 0.575
# epoch:11 | 0.116 - 0.565
# epoch:12 | 0.117 - 0.584
# epoch:13 | 0.116 - 0.578
# epoch:14 | 0.116 - 0.586
# epoch:15 | 0.117 - 0.608
# epoch:16 | 0.116 - 0.567
# epoch:17 | 0.117 - 0.558
# No handles with labels found to put in legend.
# epoch:18 | 0.117 - 0.58
# epoch:19 | 0.117 - 0.554
# ============== 15/16 ==============
# epoch:0 | 0.092 - 0.102
# epoch:1 | 0.116 - 0.427
# epoch:2 | 0.116 - 0.46
# epoch:3 | 0.116 - 0.498
# epoch:4 | 0.116 - 0.485
# epoch:5 | 0.116 - 0.598
# epoch:6 | 0.116 - 0.589
# epoch:7 | 0.116 - 0.597
# epoch:8 | 0.116 - 0.597
# epoch:9 | 0.116 - 0.587
# epoch:10 | 0.117 - 0.604
# epoch:11 | 0.117 - 0.605
# epoch:12 | 0.117 - 0.594
# epoch:13 | 0.117 - 0.608
# epoch:14 | 0.117 - 0.612
# epoch:15 | 0.117 - 0.609
# epoch:16 | 0.117 - 0.607
# epoch:17 | 0.117 - 0.613
# epoch:18 | 0.117 - 0.613
# No handles with labels found to put in legend.
# epoch:19 | 0.117 - 0.62
# ============== 16/16 ==============
# epoch:0 | 0.105 - 0.105
# epoch:1 | 0.105 - 0.228
# epoch:2 | 0.116 - 0.379
# epoch:3 | 0.116 - 0.403
# epoch:4 | 0.116 - 0.484
# epoch:5 | 0.116 - 0.479
# epoch:6 | 0.116 - 0.5
# epoch:7 | 0.116 - 0.287
# epoch:8 | 0.116 - 0.466
# epoch:9 | 0.117 - 0.511
# epoch:10 | 0.117 - 0.509
# epoch:11 | 0.116 - 0.491
# epoch:12 | 0.116 - 0.489
# epoch:13 | 0.117 - 0.518
# epoch:14 | 0.117 - 0.52
# epoch:15 | 0.117 - 0.514
# epoch:16 | 0.117 - 0.504
# epoch:17 | 0.117 - 0.519
# epoch:18 | 0.117 - 0.523
# epoch:19 | 0.117 - 0.525

# %% [markdown]
# ### 6.4.1 過学習

# %%
(x_train, y_train), (x_test, y_test) = load_mnist(normalize=True)
x_train = x_train[:300]
y_train = y_train[:300]

# %%
np.random.choice(100, 12)
# Out:
# array([ 5,  4, 49, 92,  5, 93, 99, 75, 90, 48, 73, 26])

# %%
from common.multi_layer_net import MultiLayerNet
network = MultiLayerNet(input_size=784, hidden_size_list=[100,100,100,100,100],
                        output_size=10,weight_decay_lambda=0.1)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)
    
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        
        epoch_cnt += 1
        if epoch_cnt > max_epochs:
            break

# %%
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs+1)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()

# %%
class Dropout:
    def __init_(self, dropout_ratio):
        self.dropout_ratio = dropout_ratio
        self.mask = None
        
    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)
    
    def backward(self, dout):
        return dout * self.mask

# %%
x = np.array([0,1,2,3])
np.random.rand(*x.shape)
# Out:
# array([0.12816759, 0.17239118, 0.61820337, 0.06056344])

# %%
# coding: utf-8
import os
import sys
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net_extend import MultiLayerNetExtend
from common.trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# Dropuoutの有無、割り合いの設定 ========================
use_dropout = True  # Dropoutなしのときの場合はFalseに
dropout_ratio = 0.2
# ====================================================

network = MultiLayerNetExtend(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                              output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=301, mini_batch_size=100,
                  optimizer='sgd', optimizer_param={'lr': 0.01}, verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# グラフの描画==========
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.2983478801760286
# === epoch:1, train acc:0.1, test acc:0.0977 ===
# train loss:2.299035574976133
# train loss:2.318146686589451
# train loss:2.32363852451586
# === epoch:2, train acc:0.1, test acc:0.1001 ===
# train loss:2.2877815895268925
# train loss:2.301383967525324
# train loss:2.2990826883005293
# === epoch:3, train acc:0.10666666666666667, test acc:0.1005 ===
# train loss:2.305721202208228
# train loss:2.31191644312267
# train loss:2.3214327967315307
# === epoch:4, train acc:0.11333333333333333, test acc:0.0998 ===
# train loss:2.2994984479912954
# train loss:2.3172413927060775
# train loss:2.293330557848333
# === epoch:5, train acc:0.11666666666666667, test acc:0.1031 ===
# train loss:2.293697524343823
# train loss:2.311022582098583
# train loss:2.2775400900544844
# === epoch:6, train acc:0.12333333333333334, test acc:0.1056 ===
# train loss:2.312254102426084
# train loss:2.30278829496177
# train loss:2.301317943873757
# === epoch:7, train acc:0.12, test acc:0.1067 ===
# train loss:2.307193846100173
# train loss:2.2854641266892597
# train loss:2.299841662140856
# === epoch:8, train acc:0.12666666666666668, test acc:0.1069 ===
# train loss:2.293205894000331
# train loss:2.291142933879308
# train loss:2.2953271873129864
# === epoch:9, train acc:0.12666666666666668, test acc:0.1078 ===
# train loss:2.2847839001821795
# train loss:2.2671849221033047
# train loss:2.302412997399721
# === epoch:10, train acc:0.13333333333333333, test acc:0.1098 ===
# train loss:2.280753067462293
# train loss:2.31451850877795
# train loss:2.2809962740571734
# === epoch:11, train acc:0.13666666666666666, test acc:0.1111 ===
# train loss:2.299115067547679
# train loss:2.274036031084452
# train loss:2.290303722541345
# === epoch:12, train acc:0.13, test acc:0.1124 ===
# train loss:2.2692700102175243
# train loss:2.2931854789538755
# train loss:2.2834517026359973
# === epoch:13, train acc:0.13, test acc:0.1164 ===
# train loss:2.280309152216025
# train loss:2.288187712262653
# train loss:2.290973851105866
# === epoch:14, train acc:0.13333333333333333, test acc:0.1153 ===
# train loss:2.2947315170794056
# train loss:2.264965847879425
# train loss:2.299415176834982
# === epoch:15, train acc:0.12666666666666668, test acc:0.1161 ===
# train loss:2.290183431160434
# train loss:2.2875673380277335
# train loss:2.296224322695789
# === epoch:16, train acc:0.12, test acc:0.1192 ===
# train loss:2.2890881715420024
# train loss:2.2654125677857264
# train loss:2.292337026930366
# === epoch:17, train acc:0.12, test acc:0.1198 ===
# train loss:2.2658892649111233
# train loss:2.278518924577058
# train loss:2.284208692740884
# === epoch:18, train acc:0.12333333333333334, test acc:0.1211 ===
# train loss:2.272041239647768
# train loss:2.2952868801231805
# train loss:2.310560188785482
# === epoch:19, train acc:0.12333333333333334, test acc:0.1236 ===
# train loss:2.2717858076007924
# train loss:2.2973861628498895
# train loss:2.282770969987204
# === epoch:20, train acc:0.12666666666666668, test acc:0.1254 ===
# train loss:2.273647471184988
# train loss:2.2728499887151865
# train loss:2.2794568011990712
# === epoch:21, train acc:0.12666666666666668, test acc:0.1262 ===
# train loss:2.2677619420616337
# train loss:2.2682801640036674
# train loss:2.264198670314841
# === epoch:22, train acc:0.12, test acc:0.1262 ===
# train loss:2.273966348297073
# train loss:2.2612905963795655
# train loss:2.275692256317013
# === epoch:23, train acc:0.12333333333333334, test acc:0.1266 ===
# train loss:2.26113435618528
# train loss:2.256850243300558
# train loss:2.265930167799516
# === epoch:24, train acc:0.12333333333333334, test acc:0.1265 ===
# train loss:2.261697476665285
# train loss:2.262041746086972
# train loss:2.2721573165439883
# === epoch:25, train acc:0.12333333333333334, test acc:0.1286 ===
# train loss:2.2583816639848417
# train loss:2.260814870284703
# train loss:2.256742047707458
# === epoch:26, train acc:0.12333333333333334, test acc:0.1272 ===
# train loss:2.2641189123291308
# train loss:2.266583231361936
# train loss:2.275573986183103
# === epoch:27, train acc:0.13333333333333333, test acc:0.1278 ===
# train loss:2.2664880060982204
# train loss:2.286304644135246
# train loss:2.2710050636182983
# === epoch:28, train acc:0.13666666666666666, test acc:0.1323 ===
# train loss:2.257139963419404
# train loss:2.287184871813979
# train loss:2.2519220041599053
# === epoch:29, train acc:0.13333333333333333, test acc:0.134 ===
# train loss:2.270136469177666
# train loss:2.2691910322994904
# train loss:2.2696924612058225
# === epoch:30, train acc:0.14333333333333334, test acc:0.1354 ===
# train loss:2.2576358965313172
# train loss:2.2647301395801915
# train loss:2.2763698768293774
# === epoch:31, train acc:0.15, test acc:0.136 ===
# train loss:2.255677175085862
# train loss:2.2554364575375243
# train loss:2.2631005832954405
# === epoch:32, train acc:0.16333333333333333, test acc:0.1379 ===
# train loss:2.2534242497746444
# train loss:2.265773639708791
# train loss:2.254089943994137
# === epoch:33, train acc:0.16333333333333333, test acc:0.1359 ===
# train loss:2.250658463966935
# train loss:2.2744529184790494
# train loss:2.256167943131327
# === epoch:34, train acc:0.14666666666666667, test acc:0.1341 ===
# train loss:2.243774632068538
# train loss:2.2597907118665965
# train loss:2.2611845005512374
# === epoch:35, train acc:0.15333333333333332, test acc:0.1363 ===
# train loss:2.2458135884353316
# train loss:2.2475300703799546
# train loss:2.2392082277653618
# === epoch:36, train acc:0.15333333333333332, test acc:0.1326 ===
# train loss:2.269141875868747
# train loss:2.260005122714406
# train loss:2.263334044141821
# === epoch:37, train acc:0.15333333333333332, test acc:0.1334 ===
# train loss:2.2549628368913672
# train loss:2.2677584375747823
# train loss:2.251970524170616
# === epoch:38, train acc:0.16333333333333333, test acc:0.1376 ===
# train loss:2.2459921852673244
# train loss:2.251631390843945
# train loss:2.2512028407687312
# === epoch:39, train acc:0.16666666666666666, test acc:0.1411 ===
# train loss:2.2518778254958165
# train loss:2.270132286057139
# train loss:2.229920259928898
# === epoch:40, train acc:0.16666666666666666, test acc:0.144 ===
# train loss:2.2278619267047866
# train loss:2.254312128534248
# train loss:2.24773861144924
# === epoch:41, train acc:0.16333333333333333, test acc:0.1453 ===
# train loss:2.238397751564765
# train loss:2.2502874790861
# train loss:2.2605659907036255
# === epoch:42, train acc:0.17333333333333334, test acc:0.1484 ===
# train loss:2.2587522042021937
# train loss:2.2746990464727563
# train loss:2.26034990004714
# === epoch:43, train acc:0.17666666666666667, test acc:0.1537 ===
# train loss:2.257697096680725
# train loss:2.2424503401850484
# train loss:2.2692227054931338
# === epoch:44, train acc:0.18666666666666668, test acc:0.1535 ===
# train loss:2.2531136394807323
# train loss:2.234062657478357
# train loss:2.2421693998558925
# === epoch:45, train acc:0.18666666666666668, test acc:0.154 ===
# train loss:2.249295992455067
# train loss:2.213393516601165
# train loss:2.2143927980817653
# === epoch:46, train acc:0.18333333333333332, test acc:0.1476 ===
# train loss:2.2587880702859224
# train loss:2.2208203224753706
# train loss:2.229967479486733
# === epoch:47, train acc:0.18, test acc:0.1451 ===
# train loss:2.2509585327715573
# train loss:2.228462529673996
# train loss:2.2617692933838165
# === epoch:48, train acc:0.18333333333333332, test acc:0.1506 ===
# train loss:2.2433117116393877
# train loss:2.2400373530457287
# train loss:2.244399190849115
# === epoch:49, train acc:0.19333333333333333, test acc:0.1512 ===
# train loss:2.229969019840089
# train loss:2.240945751239924
# train loss:2.253147762544368
# === epoch:50, train acc:0.19666666666666666, test acc:0.1554 ===
# train loss:2.223933250639502
# train loss:2.228236165523459
# train loss:2.2267049590173618
# === epoch:51, train acc:0.19, test acc:0.1453 ===
# train loss:2.232438314623625
# train loss:2.243859917570652
# train loss:2.2113249439084064
# === epoch:52, train acc:0.19, test acc:0.1469 ===
# train loss:2.2121060525357974
# train loss:2.2452998260199433
# train loss:2.222673249429295
# === epoch:53, train acc:0.18666666666666668, test acc:0.1459 ===
# train loss:2.2156865259468344
# train loss:2.248644092335308
# train loss:2.2428514329950264
# === epoch:54, train acc:0.19333333333333333, test acc:0.1523 ===
# train loss:2.217592882591585
# train loss:2.2180107041725674
# train loss:2.203013369646942
# === epoch:55, train acc:0.19333333333333333, test acc:0.151 ===
# train loss:2.2231593106583274
# train loss:2.220122108175592
# train loss:2.2159927147534333
# === epoch:56, train acc:0.19666666666666666, test acc:0.1489 ===
# train loss:2.22219666942386
# train loss:2.203473980711534
# train loss:2.2329521498889027
# === epoch:57, train acc:0.19333333333333333, test acc:0.1463 ===
# train loss:2.2061681198148766
# train loss:2.239898380199496
# train loss:2.2326172202092742
# === epoch:58, train acc:0.2, test acc:0.1513 ===
# train loss:2.1835910949186625
# train loss:2.1916205889604283
# train loss:2.211610968468706
# === epoch:59, train acc:0.20666666666666667, test acc:0.154 ===
# train loss:2.219602124651227
# train loss:2.2063562814878592
# train loss:2.253610331359648
# === epoch:60, train acc:0.22, test acc:0.162 ===
# train loss:2.1982448822114784
# train loss:2.1964140907755008
# train loss:2.2006877807828813
# === epoch:61, train acc:0.21666666666666667, test acc:0.1595 ===
# train loss:2.1638826568741756
# train loss:2.187605544588344
# train loss:2.2231786845403874
# === epoch:62, train acc:0.20666666666666667, test acc:0.1506 ===
# train loss:2.206183820447261
# train loss:2.2022017624566117
# train loss:2.2254024658097378
# === epoch:63, train acc:0.2, test acc:0.1505 ===
# train loss:2.1965903451585094
# train loss:2.2032868565692083
# train loss:2.215132597174126
# === epoch:64, train acc:0.21333333333333335, test acc:0.1521 ===
# train loss:2.23595124554823
# train loss:2.2188487091030558
# train loss:2.165936844400187
# === epoch:65, train acc:0.20666666666666667, test acc:0.1527 ===
# train loss:2.209836652044374
# train loss:2.1783102701242982
# train loss:2.1714760514132454
# === epoch:66, train acc:0.21, test acc:0.1531 ===
# train loss:2.1714199052268954
# train loss:2.1843097399624556
# train loss:2.1545871331644815
# === epoch:67, train acc:0.19333333333333333, test acc:0.1458 ===
# train loss:2.1607171275920005
# train loss:2.1978087954661913
# train loss:2.1202139852445074
# === epoch:68, train acc:0.19, test acc:0.1407 ===
# train loss:2.200766779447886
# train loss:2.195105184513028
# train loss:2.159133113402776
# === epoch:69, train acc:0.18666666666666668, test acc:0.1425 ===
# train loss:2.218491077291993
# train loss:2.177008307238298
# train loss:2.1613016213871568
# === epoch:70, train acc:0.21666666666666667, test acc:0.153 ===
# train loss:2.2280602937325624
# train loss:2.154297811689004
# train loss:2.2037384906598527
# === epoch:71, train acc:0.22333333333333333, test acc:0.1566 ===
# train loss:2.176543835492842
# train loss:2.160401231795928
# train loss:2.1635804994097625
# === epoch:72, train acc:0.22, test acc:0.1573 ===
# train loss:2.221551098675754
# train loss:2.182810818604158
# train loss:2.1610817007296004
# === epoch:73, train acc:0.24, test acc:0.1668 ===
# train loss:2.1664557828131326
# train loss:2.1701745620096418
# train loss:2.150022552964676
# === epoch:74, train acc:0.24, test acc:0.1661 ===
# train loss:2.194482936299083
# train loss:2.179099200390003
# train loss:2.1650472195576693
# === epoch:75, train acc:0.24333333333333335, test acc:0.1709 ===
# train loss:2.167048882025622
# train loss:2.205112900260174
# train loss:2.163051347773507
# === epoch:76, train acc:0.24333333333333335, test acc:0.1748 ===
# train loss:2.2233648435346898
# train loss:2.1535566933818515
# train loss:2.1416534617381555
# === epoch:77, train acc:0.24333333333333335, test acc:0.1766 ===
# train loss:2.149901061326128
# train loss:2.1657830466211987
# train loss:2.166275581540644
# === epoch:78, train acc:0.24666666666666667, test acc:0.1772 ===
# train loss:2.1577854865195816
# train loss:2.1702059873933495
# train loss:2.193098874780461
# === epoch:79, train acc:0.27, test acc:0.1838 ===
# train loss:2.1476713438887276
# train loss:2.1704276933889615
# train loss:2.1916211877802962
# === epoch:80, train acc:0.2733333333333333, test acc:0.1889 ===
# train loss:2.1695673149074137
# train loss:2.14707850478152
# train loss:2.1217514364046584
# === epoch:81, train acc:0.2833333333333333, test acc:0.1913 ===
# train loss:2.168007266654071
# train loss:2.1857264912601506
# train loss:2.161708398406
# === epoch:82, train acc:0.29333333333333333, test acc:0.2007 ===
# train loss:2.1467402677836884
# train loss:2.1239523346912934
# train loss:2.1571332553225138
# === epoch:83, train acc:0.29, test acc:0.1993 ===
# train loss:2.104731377342667
# train loss:2.164547916883429
# train loss:2.140088490579599
# === epoch:84, train acc:0.2866666666666667, test acc:0.2015 ===
# train loss:2.15295977772016
# train loss:2.152758838954378
# train loss:2.1148308957540998
# === epoch:85, train acc:0.29, test acc:0.203 ===
# train loss:2.1348448111015457
# train loss:2.131001575781772
# train loss:2.110409911250344
# === epoch:86, train acc:0.29, test acc:0.2076 ===
# train loss:2.1362136905674403
# train loss:2.1267354690628424
# train loss:2.191182141749211
# === epoch:87, train acc:0.29333333333333333, test acc:0.2134 ===
# train loss:2.138731384850893
# train loss:2.190556333574036
# train loss:2.1583339503064582
# === epoch:88, train acc:0.31333333333333335, test acc:0.2219 ===
# train loss:2.140183507201572
# train loss:2.1455722341397676
# train loss:2.118384303045244
# === epoch:89, train acc:0.3233333333333333, test acc:0.2268 ===
# train loss:2.137670810220412
# train loss:2.152284962517337
# train loss:2.0655660692957487
# === epoch:90, train acc:0.3233333333333333, test acc:0.2291 ===
# train loss:2.0755801600485024
# train loss:2.107548846862916
# train loss:2.1666253734950054
# === epoch:91, train acc:0.32, test acc:0.229 ===
# train loss:2.163532238225441
# train loss:2.096851884142987
# train loss:2.0689306711871116
# === epoch:92, train acc:0.30666666666666664, test acc:0.2214 ===
# train loss:2.1298979819690254
# train loss:2.1173757745715736
# train loss:2.0982172734597206
# === epoch:93, train acc:0.30666666666666664, test acc:0.2242 ===
# train loss:2.110430207127606
# train loss:2.1013796512258898
# train loss:2.1152503074368596
# === epoch:94, train acc:0.30666666666666664, test acc:0.2252 ===
# train loss:2.0704330488336877
# train loss:2.1324695697117444
# train loss:2.1020418547296655
# === epoch:95, train acc:0.31, test acc:0.2283 ===
# train loss:2.0969767992491954
# train loss:2.1801340545971732
# train loss:2.1700837249566542
# === epoch:96, train acc:0.32666666666666666, test acc:0.2339 ===
# train loss:2.0941512142857066
# train loss:2.191356888551574
# train loss:2.1209512803982964
# === epoch:97, train acc:0.3333333333333333, test acc:0.2384 ===
# train loss:2.144084988211078
# train loss:2.079341565610017
# train loss:2.0367052272897657
# === epoch:98, train acc:0.33, test acc:0.2375 ===
# train loss:2.0829322318228787
# train loss:2.0882169459787097
# train loss:2.156804424052752
# === epoch:99, train acc:0.3466666666666667, test acc:0.2446 ===
# train loss:2.092337298794459
# train loss:2.0657826371204737
# train loss:2.0942832169403105
# === epoch:100, train acc:0.3433333333333333, test acc:0.246 ===
# train loss:2.0568560190891274
# train loss:2.069327134688399
# train loss:2.0492794326290342
# === epoch:101, train acc:0.3466666666666667, test acc:0.2438 ===
# train loss:2.0859473931695787
# train loss:2.0097909211377125
# train loss:2.091683063704878
# === epoch:102, train acc:0.3466666666666667, test acc:0.2467 ===
# train loss:2.10653005545442
# train loss:2.042322340282119
# train loss:2.08568825134011
# === epoch:103, train acc:0.35333333333333333, test acc:0.2562 ===
# train loss:2.065531339891275
# train loss:2.1048988250390113
# train loss:2.0608894205341426
# === epoch:104, train acc:0.36, test acc:0.2593 ===
# train loss:2.10576375037311
# train loss:2.093295204656363
# train loss:2.11351904409309
# === epoch:105, train acc:0.3566666666666667, test acc:0.2633 ===
# train loss:2.0751692156493586
# train loss:2.126792288959423
# train loss:2.049336762261237
# === epoch:106, train acc:0.36333333333333334, test acc:0.27 ===
# train loss:2.096558204140284
# train loss:2.0257270436906154
# train loss:2.050095635880148
# === epoch:107, train acc:0.36666666666666664, test acc:0.2767 ===
# train loss:2.052210982006252
# train loss:2.078940454632871
# train loss:1.9531241833049893
# === epoch:108, train acc:0.37333333333333335, test acc:0.2784 ===
# train loss:2.111986599425468
# train loss:2.015935255213748
# train loss:2.032360133721516
# === epoch:109, train acc:0.38666666666666666, test acc:0.28 ===
# train loss:2.072136953874204
# train loss:2.0635251623113926
# train loss:2.1092941113717987
# === epoch:110, train acc:0.39666666666666667, test acc:0.2847 ===
# train loss:2.029857970926199
# train loss:2.0078777126529097
# train loss:2.0201794136166016
# === epoch:111, train acc:0.39666666666666667, test acc:0.2854 ===
# train loss:1.9992456855443448
# train loss:2.0906998789812676
# train loss:2.050077809342
# === epoch:112, train acc:0.4, test acc:0.2892 ===
# train loss:2.0422516435855678
# train loss:2.095386702783425
# train loss:2.0778208882874067
# === epoch:113, train acc:0.41, test acc:0.2938 ===
# train loss:2.0575781347507713
# train loss:1.969097583482718
# train loss:1.9348455924289738
# === epoch:114, train acc:0.4066666666666667, test acc:0.2924 ===
# train loss:2.0432389338492767
# train loss:1.974056972771941
# train loss:2.045020827317821
# === epoch:115, train acc:0.41333333333333333, test acc:0.2923 ===
# train loss:2.000014108915807
# train loss:2.062709921678597
# train loss:2.0778920085314705
# === epoch:116, train acc:0.42333333333333334, test acc:0.2988 ===
# train loss:2.076490049696879
# train loss:2.034713474255732
# train loss:2.0048916033771365
# === epoch:117, train acc:0.44333333333333336, test acc:0.3018 ===
# train loss:1.9781255498362995
# train loss:2.0595594613775234
# train loss:2.0891475218525817
# === epoch:118, train acc:0.46, test acc:0.3114 ===
# train loss:2.0438296783685796
# train loss:2.042815287591965
# train loss:2.0655328888780273
# === epoch:119, train acc:0.4633333333333333, test acc:0.3149 ===
# train loss:2.0197140171313737
# train loss:2.0536486386811474
# train loss:2.040709296366591
# === epoch:120, train acc:0.47, test acc:0.3213 ===
# train loss:1.8938376543136848
# train loss:2.051723350708428
# train loss:1.9888691149789155
# === epoch:121, train acc:0.4666666666666667, test acc:0.3237 ===
# train loss:1.9716211389818765
# train loss:1.9511140419531505
# train loss:2.0014981665751974
# === epoch:122, train acc:0.47, test acc:0.3237 ===
# train loss:2.048461987080522
# train loss:2.021110358699101
# train loss:2.0381553078228722
# === epoch:123, train acc:0.47, test acc:0.3287 ===
# train loss:2.014418496561668
# train loss:1.9792699033009276
# train loss:1.968614005020902
# === epoch:124, train acc:0.47333333333333333, test acc:0.3317 ===
# train loss:1.9591025000161597
# train loss:2.0165717274212405
# train loss:1.9876668844915715
# === epoch:125, train acc:0.4766666666666667, test acc:0.3357 ===
# train loss:1.9914898800705365
# train loss:2.014865698531043
# train loss:2.021796924574838
# === epoch:126, train acc:0.4766666666666667, test acc:0.3374 ===
# train loss:1.9966116558933649
# train loss:1.9359669888013127
# train loss:1.9603721952038191
# === epoch:127, train acc:0.4766666666666667, test acc:0.3395 ===
# train loss:1.9565114620131236
# train loss:1.9965622722398073
# train loss:2.0167391027848978
# === epoch:128, train acc:0.48, test acc:0.3469 ===
# train loss:1.9708111960393486
# train loss:1.9348432501889254
# train loss:1.989758538558215
# === epoch:129, train acc:0.48333333333333334, test acc:0.3492 ===
# train loss:1.950008792934074
# train loss:1.9248934881356192
# train loss:1.900585297845191
# === epoch:130, train acc:0.48, test acc:0.3486 ===
# train loss:1.9765261923569772
# train loss:1.9442030645047035
# train loss:2.0373224120075495
# === epoch:131, train acc:0.48, test acc:0.3544 ===
# train loss:1.9950154889901135
# train loss:1.957113453649232
# train loss:1.9068749350397258
# === epoch:132, train acc:0.4766666666666667, test acc:0.3569 ===
# train loss:2.0073733722031255
# train loss:2.0676245661573525
# train loss:1.8497576128940514
# === epoch:133, train acc:0.4766666666666667, test acc:0.358 ===
# train loss:1.9607596427040657
# train loss:1.8517545890806932
# train loss:1.9423584426377978
# === epoch:134, train acc:0.47333333333333333, test acc:0.361 ===
# train loss:1.9585338035092599
# train loss:1.9295551323590712
# train loss:1.87985942212451
# === epoch:135, train acc:0.48, test acc:0.3605 ===
# train loss:1.9884800678323344
# train loss:1.9657023086559828
# train loss:1.9150931904143607
# === epoch:136, train acc:0.48333333333333334, test acc:0.3611 ===
# train loss:1.987471618767935
# train loss:1.8675971744344644
# train loss:1.9178461705053926
# === epoch:137, train acc:0.47333333333333333, test acc:0.3639 ===
# train loss:1.9405742289456844
# train loss:1.9614519120622609
# train loss:1.895951038581181
# === epoch:138, train acc:0.47333333333333333, test acc:0.3657 ===
# train loss:1.8880937838954455
# train loss:1.9303341236323153
# train loss:1.995707516204768
# === epoch:139, train acc:0.4766666666666667, test acc:0.3686 ===
# train loss:1.8943553126345043
# train loss:1.91176748911383
# train loss:1.876800509288404
# === epoch:140, train acc:0.47333333333333333, test acc:0.3666 ===
# train loss:1.953508267772336
# train loss:1.9907295665610778
# train loss:2.0251420575812524
# === epoch:141, train acc:0.4766666666666667, test acc:0.3709 ===
# train loss:1.9530897393326785
# train loss:1.9061746353233562
# train loss:1.8268001824491353
# === epoch:142, train acc:0.4766666666666667, test acc:0.3721 ===
# train loss:1.9076058576891293
# train loss:1.8953467545685312
# train loss:1.93350080545786
# === epoch:143, train acc:0.48333333333333334, test acc:0.3743 ===
# train loss:1.9264005264395323
# train loss:1.8985358203096083
# train loss:1.949591360059255
# === epoch:144, train acc:0.4866666666666667, test acc:0.3755 ===
# train loss:1.8922481463575194
# train loss:1.9112748051927824
# train loss:1.8320795182931207
# === epoch:145, train acc:0.48333333333333334, test acc:0.3744 ===
# train loss:1.855672822034582
# train loss:1.9057039506649351
# train loss:1.9763552082869327
# === epoch:146, train acc:0.4866666666666667, test acc:0.379 ===
# train loss:1.9016279939130782
# train loss:1.871289803857658
# train loss:1.8445930577032421
# === epoch:147, train acc:0.4866666666666667, test acc:0.3797 ===
# train loss:1.7530581721810572
# train loss:1.885247904233651
# train loss:1.737706825225071
# === epoch:148, train acc:0.48333333333333334, test acc:0.3766 ===
# train loss:1.9799324285885649
# train loss:1.8349964568864805
# train loss:1.9977418993159346
# === epoch:149, train acc:0.48, test acc:0.3781 ===
# train loss:1.779365968684188
# train loss:1.8863670102000154
# train loss:1.8420755614237563
# === epoch:150, train acc:0.48, test acc:0.3783 ===
# train loss:1.8090232947325813
# train loss:1.908105598964841
# train loss:1.852293257567369
# === epoch:151, train acc:0.48333333333333334, test acc:0.3813 ===
# train loss:1.8581374939392197
# train loss:1.7915904395383289
# train loss:1.803489622009326
# === epoch:152, train acc:0.4766666666666667, test acc:0.3823 ===
# train loss:1.8605063963515207
# train loss:1.8786337434330806
# train loss:1.9345664572997054
# === epoch:153, train acc:0.4766666666666667, test acc:0.3823 ===
# train loss:1.978672532741374
# train loss:1.8875053047614108
# train loss:1.9049561384146292
# === epoch:154, train acc:0.48, test acc:0.385 ===
# train loss:1.8931647110308405
# train loss:1.9251546948448754
# train loss:1.904891137048683
# === epoch:155, train acc:0.4866666666666667, test acc:0.389 ===
# train loss:1.7370806708237339
# train loss:1.95377293194797
# train loss:1.7198239261500874
# === epoch:156, train acc:0.48333333333333334, test acc:0.3866 ===
# train loss:1.8863088371730903
# train loss:1.884299329526617
# train loss:1.808379190017143
# === epoch:157, train acc:0.4866666666666667, test acc:0.3892 ===
# train loss:1.8239331731354254
# train loss:1.771046207057427
# train loss:1.840718764880205
# === epoch:158, train acc:0.4866666666666667, test acc:0.3905 ===
# train loss:1.9815801018363675
# train loss:1.7393898546150799
# train loss:1.7982397167762454
# === epoch:159, train acc:0.49, test acc:0.3913 ===
# train loss:1.744115600724271
# train loss:1.7904439858024366
# train loss:1.793084878869145
# === epoch:160, train acc:0.4866666666666667, test acc:0.3904 ===
# train loss:1.802044763314139
# train loss:1.8191111673241833
# train loss:1.6769108624357516
# === epoch:161, train acc:0.4866666666666667, test acc:0.3886 ===
# train loss:1.7925919951318101
# train loss:1.7867444628511424
# train loss:1.8767572033099953
# === epoch:162, train acc:0.4766666666666667, test acc:0.3901 ===
# train loss:1.814548507218853
# train loss:1.781464412676653
# train loss:1.7021280119188718
# === epoch:163, train acc:0.4766666666666667, test acc:0.3901 ===
# train loss:1.775720646264503
# train loss:1.8202095493984283
# train loss:1.800438419998472
# === epoch:164, train acc:0.4766666666666667, test acc:0.3923 ===
# train loss:1.712647145476418
# train loss:1.692604695713778
# train loss:1.7446946121695748
# === epoch:165, train acc:0.4766666666666667, test acc:0.3909 ===
# train loss:1.74159500643477
# train loss:1.7630190379534745
# train loss:1.8091964750586147
# === epoch:166, train acc:0.4866666666666667, test acc:0.3911 ===
# train loss:1.7404174226661977
# train loss:1.830006242665602
# train loss:1.7406776490175762
# === epoch:167, train acc:0.4866666666666667, test acc:0.3926 ===
# train loss:1.703803483265868
# train loss:1.7854131749112452
# train loss:1.6495927177958691
# === epoch:168, train acc:0.48, test acc:0.3891 ===
# train loss:1.787388113064994
# train loss:1.8194902179317887
# train loss:1.8300428580415942
# === epoch:169, train acc:0.48333333333333334, test acc:0.3918 ===
# train loss:1.7843417413627853
# train loss:1.681540833825043
# train loss:1.703780272088666
# === epoch:170, train acc:0.48, test acc:0.3892 ===
# train loss:1.7308121169242565
# train loss:1.6653418005089862
# train loss:1.6546063660936634
# === epoch:171, train acc:0.47333333333333333, test acc:0.3877 ===
# train loss:1.733037922975666
# train loss:1.716108561999434
# train loss:1.7677786978160663
# === epoch:172, train acc:0.4766666666666667, test acc:0.3883 ===
# train loss:1.6359361601446922
# train loss:1.6595140925188283
# train loss:1.7477309491962183
# === epoch:173, train acc:0.48, test acc:0.3896 ===
# train loss:1.6920632360167949
# train loss:1.6138246497593676
# train loss:1.6026639747730105
# === epoch:174, train acc:0.4866666666666667, test acc:0.3903 ===
# train loss:1.7359372663919257
# train loss:1.7845634192868787
# train loss:1.7036354334398565
# === epoch:175, train acc:0.4766666666666667, test acc:0.3949 ===
# train loss:1.7027401391919852
# train loss:1.843493213082838
# train loss:1.8194793830134484
# === epoch:176, train acc:0.48, test acc:0.3966 ===
# train loss:1.730812533787572
# train loss:1.8022752231621393
# train loss:1.6740652376043772
# === epoch:177, train acc:0.48, test acc:0.397 ===
# train loss:1.6437654646884445
# train loss:1.7822444783933153
# train loss:1.7229910493220415
# === epoch:178, train acc:0.48333333333333334, test acc:0.3997 ===
# train loss:1.732851014095161
# train loss:1.7442704300726835
# train loss:1.7866490242762776
# === epoch:179, train acc:0.48333333333333334, test acc:0.4023 ===
# train loss:1.6749193666341866
# train loss:1.6074824319204601
# train loss:1.7553673565494272
# === epoch:180, train acc:0.48333333333333334, test acc:0.4013 ===
# train loss:1.6022679926307688
# train loss:1.810976517048345
# train loss:1.7147094836694683
# === epoch:181, train acc:0.48333333333333334, test acc:0.4029 ===
# train loss:1.7108770669622455
# train loss:1.7346227378890606
# train loss:1.6921277127186858
# === epoch:182, train acc:0.4866666666666667, test acc:0.405 ===
# train loss:1.6717254707874327
# train loss:1.7059472851289967
# train loss:1.6335840004079563
# === epoch:183, train acc:0.4866666666666667, test acc:0.4044 ===
# train loss:1.5980121790750597
# train loss:1.6728387419638076
# train loss:1.712158270021145
# === epoch:184, train acc:0.49, test acc:0.405 ===
# train loss:1.6804179999733686
# train loss:1.7377283896893387
# train loss:1.7847359700253265
# === epoch:185, train acc:0.49333333333333335, test acc:0.4095 ===
# train loss:1.6527422580135231
# train loss:1.6486152009263133
# train loss:1.6375248033557455
# === epoch:186, train acc:0.49333333333333335, test acc:0.4095 ===
# train loss:1.6880793629045436
# train loss:1.617239430432956
# train loss:1.611735223749092
# === epoch:187, train acc:0.49, test acc:0.4083 ===
# train loss:1.7194431126112906
# train loss:1.6043207420492291
# train loss:1.6259454469886863
# === epoch:188, train acc:0.49, test acc:0.4082 ===
# train loss:1.7059578328520209
# train loss:1.6565056844725914
# train loss:1.6848936114562736
# === epoch:189, train acc:0.49666666666666665, test acc:0.4104 ===
# train loss:1.6570020668852912
# train loss:1.7406901835259916
# train loss:1.6898443849670437
# === epoch:190, train acc:0.49666666666666665, test acc:0.4105 ===
# train loss:1.6705293638361907
# train loss:1.6750292384983283
# train loss:1.7431508780314937
# === epoch:191, train acc:0.5, test acc:0.4118 ===
# train loss:1.7273490563715148
# train loss:1.5901117662248538
# train loss:1.607785179013426
# === epoch:192, train acc:0.5, test acc:0.4114 ===
# train loss:1.6897603689107359
# train loss:1.6706272999354417
# train loss:1.545393893355285
# === epoch:193, train acc:0.49666666666666665, test acc:0.4111 ===
# train loss:1.544876682860343
# train loss:1.5993078952168929
# train loss:1.6122289020586311
# === epoch:194, train acc:0.49333333333333335, test acc:0.4105 ===
# train loss:1.658045127759221
# train loss:1.5147100553201656
# train loss:1.6453905803355133
# === epoch:195, train acc:0.48333333333333334, test acc:0.41 ===
# train loss:1.7096018645919628
# train loss:1.5613879243521829
# train loss:1.6355381795980881
# === epoch:196, train acc:0.49, test acc:0.4108 ===
# train loss:1.594976491191841
# train loss:1.5748437042273766
# train loss:1.5847807954602766
# === epoch:197, train acc:0.48333333333333334, test acc:0.4081 ===
# train loss:1.7354570896989594
# train loss:1.6949574818229354
# train loss:1.6255516429165093
# === epoch:198, train acc:0.49666666666666665, test acc:0.412 ===
# train loss:1.6744937812545533
# train loss:1.5651281268146233
# train loss:1.6395975862501595
# === epoch:199, train acc:0.49666666666666665, test acc:0.4125 ===
# train loss:1.5748671213234013
# train loss:1.484479113154817
# train loss:1.5439379486775195
# === epoch:200, train acc:0.49666666666666665, test acc:0.4131 ===
# train loss:1.5973399388127072
# train loss:1.62220453139781
# train loss:1.5511523512162837
# === epoch:201, train acc:0.5066666666666667, test acc:0.4175 ===
# train loss:1.5735007837208326
# train loss:1.4035352544735349
# train loss:1.6066827469133074
# === epoch:202, train acc:0.5, test acc:0.4149 ===
# train loss:1.543839743952563
# train loss:1.559941863062221
# train loss:1.5399900803281767
# === epoch:203, train acc:0.49, test acc:0.4118 ===
# train loss:1.5656788232251875
# train loss:1.5738264378546345
# train loss:1.5341036655400524
# === epoch:204, train acc:0.49333333333333335, test acc:0.4108 ===
# train loss:1.5155658778977164
# train loss:1.6345453355645878
# train loss:1.638364592059715
# === epoch:205, train acc:0.49333333333333335, test acc:0.4112 ===
# train loss:1.5334404563083068
# train loss:1.5679864805999142
# train loss:1.4663727189737454
# === epoch:206, train acc:0.5033333333333333, test acc:0.4183 ===
# train loss:1.6769644846800134
# train loss:1.6219738381840898
# train loss:1.456030310570682
# === epoch:207, train acc:0.5066666666666667, test acc:0.4203 ===
# train loss:1.3728968838525533
# train loss:1.5735231027217613
# train loss:1.5028687969694206
# === epoch:208, train acc:0.49666666666666665, test acc:0.4163 ===
# train loss:1.5262343706559478
# train loss:1.5860006732724858
# train loss:1.6376052451770322
# === epoch:209, train acc:0.5, test acc:0.4177 ===
# train loss:1.470887516422414
# train loss:1.5742257162029094
# train loss:1.587663483884568
# === epoch:210, train acc:0.5, test acc:0.4166 ===
# train loss:1.5506417514385662
# train loss:1.6353155736357972
# train loss:1.5366507291203835
# === epoch:211, train acc:0.5066666666666667, test acc:0.4209 ===
# train loss:1.6145841076027814
# train loss:1.5153212212603835
# train loss:1.4317510311338928
# === epoch:212, train acc:0.5066666666666667, test acc:0.4219 ===
# train loss:1.3674726755585909
# train loss:1.4426316576016638
# train loss:1.536305781724199
# === epoch:213, train acc:0.5033333333333333, test acc:0.4205 ===
# train loss:1.6436717540351737
# train loss:1.5345696445057544
# train loss:1.56393913038453
# === epoch:214, train acc:0.5133333333333333, test acc:0.422 ===
# train loss:1.5571009818031276
# train loss:1.3675803892310603
# train loss:1.4767229052509256
# === epoch:215, train acc:0.51, test acc:0.4233 ===
# train loss:1.4609665399652823
# train loss:1.455097431597399
# train loss:1.4668871885886612
# === epoch:216, train acc:0.51, test acc:0.4211 ===
# train loss:1.4548365186665542
# train loss:1.3395112649081466
# train loss:1.4416641313063923
# === epoch:217, train acc:0.51, test acc:0.4216 ===
# train loss:1.4650392475143772
# train loss:1.4705094223153252
# train loss:1.4392259768540174
# === epoch:218, train acc:0.5133333333333333, test acc:0.4189 ===
# train loss:1.3149842139228767
# train loss:1.6165708315425125
# train loss:1.5165146688252882
# === epoch:219, train acc:0.5166666666666667, test acc:0.4222 ===
# train loss:1.3938620331588139
# train loss:1.497999888015455
# train loss:1.497700121647358
# === epoch:220, train acc:0.5133333333333333, test acc:0.4198 ===
# train loss:1.5307667204171667
# train loss:1.4224124317451674
# train loss:1.4561175995962174
# === epoch:221, train acc:0.5166666666666667, test acc:0.4229 ===
# train loss:1.4870408537226274
# train loss:1.5811604408448983
# train loss:1.5428465111111884
# === epoch:222, train acc:0.52, test acc:0.4251 ===
# train loss:1.4454443590788966
# train loss:1.2732538102243336
# train loss:1.4428174990370517
# === epoch:223, train acc:0.5233333333333333, test acc:0.425 ===
# train loss:1.5657878813519182
# train loss:1.4925911531456404
# train loss:1.5211609218964253
# === epoch:224, train acc:0.5266666666666666, test acc:0.4249 ===
# train loss:1.4585397524678416
# train loss:1.6287124158037052
# train loss:1.43276642702778
# === epoch:225, train acc:0.52, test acc:0.4256 ===
# train loss:1.519168277884159
# train loss:1.4370147810777245
# train loss:1.5119061012174444
# === epoch:226, train acc:0.5166666666666667, test acc:0.4279 ===
# train loss:1.4679223127641832
# train loss:1.3971459105414104
# train loss:1.428992661713848
# === epoch:227, train acc:0.51, test acc:0.4279 ===
# train loss:1.4153073147589001
# train loss:1.4938923435990439
# train loss:1.3341352814081404
# === epoch:228, train acc:0.51, test acc:0.4273 ===
# train loss:1.509612111551843
# train loss:1.491112284351328
# train loss:1.364910433106821
# === epoch:229, train acc:0.5066666666666667, test acc:0.4292 ===
# train loss:1.2900818881067837
# train loss:1.4868007409869486
# train loss:1.3421710855521078
# === epoch:230, train acc:0.5133333333333333, test acc:0.4293 ===
# train loss:1.4499816054663919
# train loss:1.4491738068517186
# train loss:1.3452371095173496
# === epoch:231, train acc:0.5266666666666666, test acc:0.431 ===
# train loss:1.4646578471476226
# train loss:1.297708004369659
# train loss:1.4542160527152916
# === epoch:232, train acc:0.53, test acc:0.4366 ===
# train loss:1.47281722252417
# train loss:1.4492631665295457
# train loss:1.5848933755014378
# === epoch:233, train acc:0.5366666666666666, test acc:0.4425 ===
# train loss:1.3301447865879767
# train loss:1.5094851340922113
# train loss:1.504473716498569
# === epoch:234, train acc:0.5366666666666666, test acc:0.4455 ===
# train loss:1.3123792393306204
# train loss:1.4196935463000129
# train loss:1.368858703926791
# === epoch:235, train acc:0.5433333333333333, test acc:0.4498 ===
# train loss:1.3938258024307395
# train loss:1.2967363212120264
# train loss:1.4708757652693643
# === epoch:236, train acc:0.5466666666666666, test acc:0.4523 ===
# train loss:1.3378538941479565
# train loss:1.25300897861702
# train loss:1.3091151102591203
# === epoch:237, train acc:0.54, test acc:0.4501 ===
# train loss:1.5164402612624865
# train loss:1.2922460114442371
# train loss:1.2962487960584408
# === epoch:238, train acc:0.54, test acc:0.4488 ===
# train loss:1.4736715094131705
# train loss:1.3562589296568113
# train loss:1.3713473530054605
# === epoch:239, train acc:0.5466666666666666, test acc:0.4523 ===
# train loss:1.4729800009685912
# train loss:1.4553829526724733
# train loss:1.251350703892001
# === epoch:240, train acc:0.54, test acc:0.4552 ===
# train loss:1.3485737847854498
# train loss:1.3566677760347752
# train loss:1.2757990565812032
# === epoch:241, train acc:0.55, test acc:0.4582 ===
# train loss:1.28099278836673
# train loss:1.4252746873853992
# train loss:1.3464285150009632
# === epoch:242, train acc:0.5433333333333333, test acc:0.4557 ===
# train loss:1.3665167325545766
# train loss:1.410157737060132
# train loss:1.529043624221591
# === epoch:243, train acc:0.5466666666666666, test acc:0.4563 ===
# train loss:1.3936343220808478
# train loss:1.50209880924491
# train loss:1.3249604764685208
# === epoch:244, train acc:0.54, test acc:0.4559 ===
# train loss:1.3821526869068501
# train loss:1.3105708981306485
# train loss:1.2627068247969668
# === epoch:245, train acc:0.5466666666666666, test acc:0.4581 ===
# train loss:1.3692971450029738
# train loss:1.255422218322114
# train loss:1.408785421334951
# === epoch:246, train acc:0.5566666666666666, test acc:0.4653 ===
# train loss:1.2235455994742415
# train loss:1.3071055104173235
# train loss:1.3607573113594251
# === epoch:247, train acc:0.56, test acc:0.4677 ===
# train loss:1.2427072743255012
# train loss:1.3787442230520515
# train loss:1.3301476560590544
# === epoch:248, train acc:0.5533333333333333, test acc:0.4655 ===
# train loss:1.3543461006410376
# train loss:1.2748880740137845
# train loss:1.2899711280337514
# === epoch:249, train acc:0.56, test acc:0.4669 ===
# train loss:1.3079857983503884
# train loss:1.451482786187241
# train loss:1.3758882386120144
# === epoch:250, train acc:0.5566666666666666, test acc:0.4679 ===
# train loss:1.2848057871910228
# train loss:1.2673552005275754
# train loss:1.3430570446414611
# === epoch:251, train acc:0.56, test acc:0.4706 ===
# train loss:1.3885481121836998
# train loss:1.474094421368746
# train loss:1.2530224465804165
# === epoch:252, train acc:0.56, test acc:0.475 ===
# train loss:1.1974604960084294
# train loss:1.219177562270495
# train loss:1.141570686345852
# === epoch:253, train acc:0.56, test acc:0.4722 ===
# train loss:1.2041550888184056
# train loss:1.3636182982063685
# train loss:1.3058320602624087
# === epoch:254, train acc:0.5566666666666666, test acc:0.4708 ===
# train loss:1.0819603513408038
# train loss:1.2778562489521623
# train loss:1.2276681771041416
# === epoch:255, train acc:0.55, test acc:0.4695 ===
# train loss:1.286405644340511
# train loss:1.3187746202521782
# train loss:1.2403998242750185
# === epoch:256, train acc:0.5633333333333334, test acc:0.47 ===
# train loss:1.2425953070494413
# train loss:1.2485202733174554
# train loss:1.2600083145348242
# === epoch:257, train acc:0.5566666666666666, test acc:0.4683 ===
# train loss:1.2654312539588104
# train loss:1.3526140272369878
# train loss:1.2029759880353756
# === epoch:258, train acc:0.5633333333333334, test acc:0.473 ===
# train loss:1.168116181073336
# train loss:1.2086568881277922
# train loss:1.2681592068657466
# === epoch:259, train acc:0.5466666666666666, test acc:0.4731 ===
# train loss:1.2561597934625937
# train loss:1.0787253449302103
# train loss:1.3055580589000522
# === epoch:260, train acc:0.56, test acc:0.4682 ===
# train loss:1.2411775862185634
# train loss:1.2475263994817531
# train loss:1.1928921877568666
# === epoch:261, train acc:0.58, test acc:0.4711 ===
# train loss:1.315670807376827
# train loss:1.251387101729632
# train loss:1.1770016543255606
# === epoch:262, train acc:0.5866666666666667, test acc:0.4737 ===
# train loss:1.33322055343716
# train loss:1.12332911550447
# train loss:1.2110932893410282
# === epoch:263, train acc:0.58, test acc:0.4754 ===
# train loss:1.2657920335808264
# train loss:1.2118519719884056
# train loss:1.3328465282456758
# === epoch:264, train acc:0.58, test acc:0.4734 ===
# train loss:1.3878568801803521
# train loss:1.2272195305600604
# train loss:1.1270492531352179
# === epoch:265, train acc:0.58, test acc:0.4735 ===
# train loss:1.3021276932455093
# train loss:1.1746265934424915
# train loss:1.3662952638839312
# === epoch:266, train acc:0.58, test acc:0.4787 ===
# train loss:1.220225949080049
# train loss:1.228783922222522
# train loss:1.2130938591102276
# === epoch:267, train acc:0.6, test acc:0.4826 ===
# train loss:1.2864161345574538
# train loss:1.2152096774763341
# train loss:1.218405093545016
# === epoch:268, train acc:0.5866666666666667, test acc:0.4814 ===
# train loss:1.2038277629414562
# train loss:1.2794295815552494
# train loss:1.2221085031104026
# === epoch:269, train acc:0.5933333333333334, test acc:0.4849 ===
# train loss:1.297007938592807
# train loss:1.3056624689463632
# train loss:1.3737511162416138
# === epoch:270, train acc:0.6166666666666667, test acc:0.4887 ===
# train loss:1.1904147299623167
# train loss:1.1688876857102202
# train loss:1.2060858112270065
# === epoch:271, train acc:0.6066666666666667, test acc:0.4899 ===
# train loss:1.1902877881801246
# train loss:1.3186817012661702
# train loss:1.1585509282086064
# === epoch:272, train acc:0.61, test acc:0.4918 ===
# train loss:1.2065112943535903
# train loss:1.0982781826152814
# train loss:1.1957903069784817
# === epoch:273, train acc:0.61, test acc:0.4928 ===
# train loss:1.1180781493781227
# train loss:1.1252625161777712
# train loss:1.081974498061709
# === epoch:274, train acc:0.6, test acc:0.4858 ===
# train loss:1.2602260248789743
# train loss:1.1605648810367732
# train loss:1.0755380685029934
# === epoch:275, train acc:0.6233333333333333, test acc:0.4895 ===
# train loss:1.099520909224019
# train loss:1.1810332052210994
# train loss:1.1029550784985551
# === epoch:276, train acc:0.61, test acc:0.4911 ===
# train loss:1.1010463511280553
# train loss:1.1351084536742184
# train loss:1.079366818288168
# === epoch:277, train acc:0.6, test acc:0.4898 ===
# train loss:1.0787580799344745
# train loss:1.1549924053470668
# train loss:1.07129661337332
# === epoch:278, train acc:0.6133333333333333, test acc:0.488 ===
# train loss:1.0556591417440844
# train loss:1.2284947110635667
# train loss:1.1007198467823804
# === epoch:279, train acc:0.6066666666666667, test acc:0.4871 ===
# train loss:1.1419254667886274
# train loss:1.189707523604836
# train loss:1.1303811410034346
# === epoch:280, train acc:0.6166666666666667, test acc:0.493 ===
# train loss:1.1438620544944345
# train loss:1.204494409488357
# train loss:1.2924511766650368
# === epoch:281, train acc:0.6266666666666667, test acc:0.493 ===
# train loss:1.1835496168508977
# train loss:1.1607793037450005
# train loss:1.106943221747755
# === epoch:282, train acc:0.6433333333333333, test acc:0.4979 ===
# train loss:1.1104178064279644
# train loss:1.1491130172260469
# train loss:0.9974480561302932
# === epoch:283, train acc:0.6366666666666667, test acc:0.4977 ===
# train loss:1.255371903859393
# train loss:1.200056753728519
# train loss:1.2145740074531977
# === epoch:284, train acc:0.64, test acc:0.5041 ===
# train loss:1.0208401944437713
# train loss:1.1459828224267163
# train loss:1.1211169091507815
# === epoch:285, train acc:0.6533333333333333, test acc:0.5077 ===
# train loss:1.256006503054479
# train loss:1.106970603296258
# train loss:1.2468316255288088
# === epoch:286, train acc:0.64, test acc:0.5063 ===
# train loss:1.1165026734019148
# train loss:1.2370737267656642
# train loss:1.3398803361864091
# === epoch:287, train acc:0.64, test acc:0.5041 ===
# train loss:1.049638717266153
# train loss:0.9661669240450604
# train loss:1.0661940992248258
# === epoch:288, train acc:0.6333333333333333, test acc:0.4996 ===
# train loss:0.9878786588538739
# train loss:1.02549448333243
# train loss:1.2206976618695562
# === epoch:289, train acc:0.6433333333333333, test acc:0.5001 ===
# train loss:1.238193180394002
# train loss:1.2263990708479624
# train loss:1.0801012109227812
# === epoch:290, train acc:0.6433333333333333, test acc:0.501 ===
# train loss:1.0713507593620228
# train loss:1.1927255607402527
# train loss:1.2057449508841505
# === epoch:291, train acc:0.6466666666666666, test acc:0.5037 ===
# train loss:1.187102707379491
# train loss:1.2657621746360253
# train loss:1.0901018610045077
# === epoch:292, train acc:0.67, test acc:0.5102 ===
# train loss:1.1712296362908796
# train loss:1.2325837713105512
# train loss:1.0524893125924613
# === epoch:293, train acc:0.6766666666666666, test acc:0.512 ===
# train loss:0.988361063491437
# train loss:1.112392451880142
# train loss:1.127850135307233
# === epoch:294, train acc:0.67, test acc:0.5112 ===
# train loss:1.1778283955079072
# train loss:0.9257316668580657
# train loss:1.068443951625113
# === epoch:295, train acc:0.67, test acc:0.515 ===
# train loss:1.0899611009930903
# train loss:1.0109591957573487
# train loss:1.1398905664891925
# === epoch:296, train acc:0.6633333333333333, test acc:0.5169 ===
# train loss:1.1286897580569468
# train loss:1.123508727889271
# train loss:0.9753918392902844
# === epoch:297, train acc:0.6733333333333333, test acc:0.5238 ===
# train loss:0.9133469320732114
# train loss:1.1530825816846666
# train loss:1.0086849554703887
# === epoch:298, train acc:0.6766666666666666, test acc:0.5234 ===
# train loss:1.0575174086109758
# train loss:1.2425821805551054
# train loss:1.043871137657683
# === epoch:299, train acc:0.6866666666666666, test acc:0.5265 ===
# train loss:0.9879235859878055
# train loss:1.0875354930953511
# train loss:1.0865429182552113
# === epoch:300, train acc:0.6866666666666666, test acc:0.5247 ===
# train loss:1.1606172578690106
# train loss:1.0628723967489
# train loss:0.9707534922852092
# === epoch:301, train acc:0.69, test acc:0.5229 ===
# train loss:1.1406345763760586
# train loss:1.1839140694224424
# =============== Final Test Accuracy ===============
# test acc:0.5258

# %%
from common.util import shuffle_dataset
(x_train, t_train), (x_test, t_test) = load_mnist()

x_train, t_train = shuffle_dataset(x_train, t_train)

validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)

x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

# %%
weight_decay = 10 ** np.random.uniform(-8, -4)
lr = 10 ** np.random.uniform(-6, -2)
print(weight_decay)
print(lr)
# Out:
# 1.4086168003574033e-06
# 7.064409168183956e-06

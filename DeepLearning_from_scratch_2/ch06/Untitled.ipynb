# %%
# coding: utf-8
import numpy as np
import matplotlib.pyplot as plt


N = 2  # ミニバッチサイズ
H = 3  # 隠れ状態ベクトルの次元数
T = 20  # 時系列データの長さ

dh = np.ones((N, H))

np.random.seed(3)

Wh = np.random.randn(H, H) * 0.5
#Wh = np.random.randn(H, H) * 0.5

norm_list = []
for t in range(T):
    dh = np.dot(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)

print(norm_list)

# グラフの描画
plt.plot(np.arange(len(norm_list)), norm_list)
plt.xticks([0, 4, 9, 14, 19], [1, 5, 10, 15, 20])
plt.xlabel('time step')
plt.ylabel('norm')
plt.show()
# Out:
# [1.2342034047289652, 0.8339262435402591, 0.5979099219216477, 0.39247420825547574, 0.2525242645318454, 0.16017442237957713, 0.10106299614538981, 0.06358148956166684, 0.03995083909833199, 0.025086887541098325, 0.015748611904532892, 0.009884999125204758, 0.006204151282595105, 0.003893806551809953, 0.002443767399386287, 0.0015337065005571365, 0.0009625497320203265, 0.0006040924319556741, 0.00037912574706291106, 0.00023793756048323344]

# %%
# coding: utf-8
import numpy as np


dW1 = np.random.rand(3, 3) * 10
dW2 = np.random.rand(3, 3) * 10
grads = [dW1, dW2]
max_norm = 5.0


def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate


print('before:', dW1.flatten())
clip_grads(grads, max_norm)
print('after:', dW1.flatten())
# Out:
# before: [6.49144048 2.78487283 6.76254902 5.90862817 0.23981882 5.58854088
#  2.59252447 4.15101197 2.83525082]
# after: [1.49503731 0.64138134 1.55747605 1.36081038 0.05523244 1.28709139
#  0.59708178 0.95601551 0.65298384]

# %%
# coding: utf-8
import sys
sys.path.append('..')
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb
from rnnlm import Rnnlm


# ハイパーパラメータの設定
batch_size = 20
wordvec_size = 100
hidden_size = 100  # RNNの隠れ状態ベクトルの要素数
time_size = 35  # RNNを展開するサイズ
lr = 20.0
max_epoch = 4
max_grad = 0.25

# 学習データの読み込み
corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# モデルの生成
model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# 勾配クリッピングを適用して学習
trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad,
            eval_interval=20)
trainer.plot(ylim=(0, 500))

# テストデータで評価
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('test perplexity: ', ppl_test)

# パラメータの保存
model.save_params()
# Out:
# Downloading ptb.test.txt ...
# Done
# | epoch 1 |  iter 1 / 1327 | time 0[s] | perplexity 9999.69
# | epoch 1 |  iter 21 / 1327 | time 3[s] | perplexity 2965.94
# | epoch 1 |  iter 41 / 1327 | time 5[s] | perplexity 1249.70
# | epoch 1 |  iter 61 / 1327 | time 8[s] | perplexity 941.48
# | epoch 1 |  iter 81 / 1327 | time 11[s] | perplexity 808.19
# | epoch 1 |  iter 101 / 1327 | time 14[s] | perplexity 665.85
# | epoch 1 |  iter 121 / 1327 | time 16[s] | perplexity 643.87
# | epoch 1 |  iter 141 / 1327 | time 19[s] | perplexity 592.84
# | epoch 1 |  iter 161 / 1327 | time 22[s] | perplexity 563.76
# | epoch 1 |  iter 181 / 1327 | time 25[s] | perplexity 593.24
# | epoch 1 |  iter 201 / 1327 | time 27[s] | perplexity 517.82
# | epoch 1 |  iter 221 / 1327 | time 30[s] | perplexity 495.32
# | epoch 1 |  iter 241 / 1327 | time 33[s] | perplexity 460.64
# | epoch 1 |  iter 261 / 1327 | time 36[s] | perplexity 478.56
# | epoch 1 |  iter 281 / 1327 | time 39[s] | perplexity 451.59
# | epoch 1 |  iter 301 / 1327 | time 42[s] | perplexity 396.88
# | epoch 1 |  iter 321 / 1327 | time 45[s] | perplexity 343.36
# | epoch 1 |  iter 341 / 1327 | time 48[s] | perplexity 416.39
# | epoch 1 |  iter 361 / 1327 | time 51[s] | perplexity 412.93
# | epoch 1 |  iter 381 / 1327 | time 54[s] | perplexity 336.94
# | epoch 1 |  iter 401 / 1327 | time 57[s] | perplexity 353.20
# | epoch 1 |  iter 421 / 1327 | time 60[s] | perplexity 344.71
# | epoch 1 |  iter 441 / 1327 | time 63[s] | perplexity 332.06
# | epoch 1 |  iter 461 / 1327 | time 66[s] | perplexity 328.53
# | epoch 1 |  iter 481 / 1327 | time 69[s] | perplexity 313.70
# | epoch 1 |  iter 501 / 1327 | time 72[s] | perplexity 313.19
# | epoch 1 |  iter 521 / 1327 | time 75[s] | perplexity 304.76
# | epoch 1 |  iter 541 / 1327 | time 78[s] | perplexity 316.39
# | epoch 1 |  iter 561 / 1327 | time 81[s] | perplexity 286.69
# | epoch 1 |  iter 581 / 1327 | time 84[s] | perplexity 260.73
# | epoch 1 |  iter 601 / 1327 | time 87[s] | perplexity 337.11
# | epoch 1 |  iter 621 / 1327 | time 90[s] | perplexity 312.83
# | epoch 1 |  iter 641 / 1327 | time 93[s] | perplexity 285.68
# | epoch 1 |  iter 661 / 1327 | time 96[s] | perplexity 268.84
# | epoch 1 |  iter 681 / 1327 | time 99[s] | perplexity 228.41
# | epoch 1 |  iter 701 / 1327 | time 102[s] | perplexity 251.91
# | epoch 1 |  iter 721 / 1327 | time 105[s] | perplexity 259.72
# | epoch 1 |  iter 741 / 1327 | time 108[s] | perplexity 221.91
# | epoch 1 |  iter 761 / 1327 | time 111[s] | perplexity 234.89
# | epoch 1 |  iter 781 / 1327 | time 114[s] | perplexity 219.87
# | epoch 1 |  iter 801 / 1327 | time 117[s] | perplexity 241.53
# | epoch 1 |  iter 821 / 1327 | time 120[s] | perplexity 224.01
# | epoch 1 |  iter 841 / 1327 | time 123[s] | perplexity 227.39
# | epoch 1 |  iter 861 / 1327 | time 126[s] | perplexity 220.32
# | epoch 1 |  iter 881 / 1327 | time 129[s] | perplexity 206.88
# | epoch 1 |  iter 901 / 1327 | time 132[s] | perplexity 254.17
# | epoch 1 |  iter 921 / 1327 | time 135[s] | perplexity 229.56
# | epoch 1 |  iter 941 / 1327 | time 138[s] | perplexity 230.52
# | epoch 1 |  iter 961 / 1327 | time 141[s] | perplexity 244.27
# | epoch 1 |  iter 981 / 1327 | time 144[s] | perplexity 230.32
# | epoch 1 |  iter 1001 / 1327 | time 147[s] | perplexity 192.85
# | epoch 1 |  iter 1021 / 1327 | time 150[s] | perplexity 227.53
# | epoch 1 |  iter 1041 / 1327 | time 153[s] | perplexity 206.94
# | epoch 1 |  iter 1061 / 1327 | time 156[s] | perplexity 195.78
# | epoch 1 |  iter 1081 / 1327 | time 159[s] | perplexity 168.38
# | epoch 1 |  iter 1101 / 1327 | time 162[s] | perplexity 192.90
# | epoch 1 |  iter 1121 / 1327 | time 165[s] | perplexity 228.72
# | epoch 1 |  iter 1141 / 1327 | time 168[s] | perplexity 207.27
# | epoch 1 |  iter 1161 / 1327 | time 171[s] | perplexity 199.36
# | epoch 1 |  iter 1181 / 1327 | time 174[s] | perplexity 190.00
# | epoch 1 |  iter 1201 / 1327 | time 177[s] | perplexity 160.78
# | epoch 1 |  iter 1221 / 1327 | time 180[s] | perplexity 158.98
# | epoch 1 |  iter 1241 / 1327 | time 183[s] | perplexity 188.36
# | epoch 1 |  iter 1261 / 1327 | time 186[s] | perplexity 172.05
# | epoch 1 |  iter 1281 / 1327 | time 189[s] | perplexity 176.76
# | epoch 1 |  iter 1301 / 1327 | time 192[s] | perplexity 221.93
# | epoch 1 |  iter 1321 / 1327 | time 195[s] | perplexity 210.54
# | epoch 2 |  iter 1 / 1327 | time 196[s] | perplexity 225.62
# | epoch 2 |  iter 21 / 1327 | time 199[s] | perplexity 204.38
# | epoch 2 |  iter 41 / 1327 | time 202[s] | perplexity 191.22
# | epoch 2 |  iter 61 / 1327 | time 205[s] | perplexity 174.83
# | epoch 2 |  iter 81 / 1327 | time 208[s] | perplexity 159.31
# | epoch 2 |  iter 101 / 1327 | time 211[s] | perplexity 152.87
# | epoch 2 |  iter 121 / 1327 | time 215[s] | perplexity 159.75
# | epoch 2 |  iter 141 / 1327 | time 218[s] | perplexity 177.56
# | epoch 2 |  iter 161 / 1327 | time 221[s] | perplexity 192.95
# | epoch 2 |  iter 181 / 1327 | time 224[s] | perplexity 200.84
# | epoch 2 |  iter 201 / 1327 | time 227[s] | perplexity 186.14
# | epoch 2 |  iter 221 / 1327 | time 230[s] | perplexity 185.13
# | epoch 2 |  iter 241 / 1327 | time 233[s] | perplexity 177.37
# | epoch 2 |  iter 261 / 1327 | time 236[s] | perplexity 186.60
# | epoch 2 |  iter 281 / 1327 | time 239[s] | perplexity 185.39
# | epoch 2 |  iter 301 / 1327 | time 242[s] | perplexity 167.09
# | epoch 2 |  iter 321 / 1327 | time 249[s] | perplexity 138.57
# | epoch 2 |  iter 341 / 1327 | time 3515[s] | perplexity 169.59
# | epoch 2 |  iter 361 / 1327 | time 3518[s] | perplexity 199.21
# | epoch 2 |  iter 381 / 1327 | time 3522[s] | perplexity 153.65
# | epoch 2 |  iter 401 / 1327 | time 3525[s] | perplexity 166.19
# | epoch 2 |  iter 421 / 1327 | time 3527[s] | perplexity 154.42
# | epoch 2 |  iter 441 / 1327 | time 3530[s] | perplexity 164.03
# | epoch 2 |  iter 461 / 1327 | time 3533[s] | perplexity 155.98
# | epoch 2 |  iter 481 / 1327 | time 3536[s] | perplexity 156.84
# | epoch 2 |  iter 501 / 1327 | time 3539[s] | perplexity 170.68
# | epoch 2 |  iter 521 / 1327 | time 3542[s] | perplexity 171.26
# | epoch 2 |  iter 541 / 1327 | time 3544[s] | perplexity 173.61
# | epoch 2 |  iter 561 / 1327 | time 3547[s] | perplexity 156.74
# | epoch 2 |  iter 581 / 1327 | time 3550[s] | perplexity 138.48
# | epoch 2 |  iter 601 / 1327 | time 3553[s] | perplexity 188.72
# | epoch 2 |  iter 621 / 1327 | time 3556[s] | perplexity 182.06
# | epoch 2 |  iter 641 / 1327 | time 3559[s] | perplexity 165.20
# | epoch 2 |  iter 661 / 1327 | time 3562[s] | perplexity 156.61
# | epoch 2 |  iter 681 / 1327 | time 3565[s] | perplexity 130.60
# | epoch 2 |  iter 701 / 1327 | time 3568[s] | perplexity 151.90
# | epoch 2 |  iter 721 / 1327 | time 3571[s] | perplexity 160.12
# | epoch 2 |  iter 741 / 1327 | time 3575[s] | perplexity 134.24
# | epoch 2 |  iter 761 / 1327 | time 3578[s] | perplexity 133.81
# | epoch 2 |  iter 781 / 1327 | time 3581[s] | perplexity 136.37
# | epoch 2 |  iter 801 / 1327 | time 3584[s] | perplexity 147.46
# | epoch 2 |  iter 821 / 1327 | time 3587[s] | perplexity 143.78
# | epoch 2 |  iter 841 / 1327 | time 3590[s] | perplexity 144.29
# | epoch 2 |  iter 861 / 1327 | time 3593[s] | perplexity 145.16
# | epoch 2 |  iter 881 / 1327 | time 3597[s] | perplexity 130.67
# | epoch 2 |  iter 901 / 1327 | time 3600[s] | perplexity 167.29
# | epoch 2 |  iter 921 / 1327 | time 3604[s] | perplexity 147.94
# | epoch 2 |  iter 941 / 1327 | time 3608[s] | perplexity 155.14
# | epoch 2 |  iter 961 / 1327 | time 3611[s] | perplexity 163.39
# | epoch 2 |  iter 981 / 1327 | time 3614[s] | perplexity 154.67
# | epoch 2 |  iter 1001 / 1327 | time 3617[s] | perplexity 131.63
# | epoch 2 |  iter 1021 / 1327 | time 3620[s] | perplexity 155.88
# | epoch 2 |  iter 1041 / 1327 | time 3623[s] | perplexity 143.00
# | epoch 2 |  iter 1061 / 1327 | time 3626[s] | perplexity 129.11
# | epoch 2 |  iter 1081 / 1327 | time 3629[s] | perplexity 111.53
# | epoch 2 |  iter 1101 / 1327 | time 3633[s] | perplexity 121.87
# | epoch 2 |  iter 1121 / 1327 | time 3636[s] | perplexity 153.78
# | epoch 2 |  iter 1141 / 1327 | time 3639[s] | perplexity 142.22
# | epoch 2 |  iter 1161 / 1327 | time 3642[s] | perplexity 133.80
# | epoch 2 |  iter 1181 / 1327 | time 3645[s] | perplexity 134.29
# | epoch 2 |  iter 1201 / 1327 | time 3648[s] | perplexity 111.56
# | epoch 2 |  iter 1221 / 1327 | time 3651[s] | perplexity 110.21
# | epoch 2 |  iter 1241 / 1327 | time 3654[s] | perplexity 131.03
# | epoch 2 |  iter 1261 / 1327 | time 3658[s] | perplexity 124.35
# | epoch 2 |  iter 1281 / 1327 | time 3661[s] | perplexity 122.72
# | epoch 2 |  iter 1301 / 1327 | time 3664[s] | perplexity 157.39
# | epoch 2 |  iter 1321 / 1327 | time 3667[s] | perplexity 152.69
# | epoch 3 |  iter 1 / 1327 | time 3668[s] | perplexity 161.69
# | epoch 3 |  iter 21 / 1327 | time 3671[s] | perplexity 144.32
# | epoch 3 |  iter 41 / 1327 | time 3674[s] | perplexity 136.82
# | epoch 3 |  iter 61 / 1327 | time 3677[s] | perplexity 126.98
# | epoch 3 |  iter 81 / 1327 | time 3680[s] | perplexity 118.49
# | epoch 3 |  iter 101 / 1327 | time 3684[s] | perplexity 106.33
# | epoch 3 |  iter 121 / 1327 | time 3687[s] | perplexity 116.84
# | epoch 3 |  iter 141 / 1327 | time 3690[s] | perplexity 127.02
# | epoch 3 |  iter 161 / 1327 | time 3693[s] | perplexity 142.49
# | epoch 3 |  iter 181 / 1327 | time 3696[s] | perplexity 151.43
# | epoch 3 |  iter 201 / 1327 | time 3699[s] | perplexity 141.73
# | epoch 3 |  iter 221 / 1327 | time 3702[s] | perplexity 141.90
# | epoch 3 |  iter 241 / 1327 | time 3705[s] | perplexity 135.59
# | epoch 3 |  iter 261 / 1327 | time 3708[s] | perplexity 140.53
# | epoch 3 |  iter 281 / 1327 | time 3711[s] | perplexity 143.36
# | epoch 3 |  iter 301 / 1327 | time 3714[s] | perplexity 123.26
# | epoch 3 |  iter 321 / 1327 | time 3717[s] | perplexity 103.06
# | epoch 3 |  iter 341 / 1327 | time 3720[s] | perplexity 125.24
# | epoch 3 |  iter 361 / 1327 | time 3723[s] | perplexity 154.04
# | epoch 3 |  iter 381 / 1327 | time 3727[s] | perplexity 114.97
# | epoch 3 |  iter 401 / 1327 | time 3730[s] | perplexity 129.14
# | epoch 3 |  iter 421 / 1327 | time 3733[s] | perplexity 113.34
# | epoch 3 |  iter 441 / 1327 | time 3736[s] | perplexity 125.38
# | epoch 3 |  iter 461 / 1327 | time 3739[s] | perplexity 118.14
# | epoch 3 |  iter 481 / 1327 | time 3742[s] | perplexity 120.39
# | epoch 3 |  iter 501 / 1327 | time 3745[s] | perplexity 129.63
# | epoch 3 |  iter 521 / 1327 | time 3748[s] | perplexity 137.60
# | epoch 3 |  iter 541 / 1327 | time 3751[s] | perplexity 135.81
# | epoch 3 |  iter 561 / 1327 | time 3754[s] | perplexity 119.60
# | epoch 3 |  iter 581 / 1327 | time 3757[s] | perplexity 105.95
# | epoch 3 |  iter 601 / 1327 | time 3760[s] | perplexity 147.76
# | epoch 3 |  iter 621 / 1327 | time 3763[s] | perplexity 143.01
# | epoch 3 |  iter 641 / 1327 | time 3766[s] | perplexity 129.34
# | epoch 3 |  iter 661 / 1327 | time 3769[s] | perplexity 122.47
# | epoch 3 |  iter 681 / 1327 | time 3772[s] | perplexity 100.62
# | epoch 3 |  iter 701 / 1327 | time 3775[s] | perplexity 120.16
# | epoch 3 |  iter 721 / 1327 | time 3778[s] | perplexity 126.80
# | epoch 3 |  iter 741 / 1327 | time 3781[s] | perplexity 109.42
# | epoch 3 |  iter 761 / 1327 | time 3784[s] | perplexity 104.75
# | epoch 3 |  iter 781 / 1327 | time 3788[s] | perplexity 105.87
# | epoch 3 |  iter 801 / 1327 | time 3791[s] | perplexity 115.76
# | epoch 3 |  iter 821 / 1327 | time 3794[s] | perplexity 117.04
# | epoch 3 |  iter 841 / 1327 | time 3797[s] | perplexity 114.94
# | epoch 3 |  iter 861 / 1327 | time 3800[s] | perplexity 120.16
# | epoch 3 |  iter 881 / 1327 | time 3803[s] | perplexity 106.94
# | epoch 3 |  iter 901 / 1327 | time 3806[s] | perplexity 133.21
# | epoch 3 |  iter 921 / 1327 | time 3809[s] | perplexity 118.54
# | epoch 3 |  iter 941 / 1327 | time 3812[s] | perplexity 127.04
# | epoch 3 |  iter 961 / 1327 | time 3815[s] | perplexity 132.12
# | epoch 3 |  iter 981 / 1327 | time 3818[s] | perplexity 123.59
# | epoch 3 |  iter 1001 / 1327 | time 3821[s] | perplexity 109.47
# | epoch 3 |  iter 1021 / 1327 | time 3824[s] | perplexity 128.86
# | epoch 3 |  iter 1041 / 1327 | time 3827[s] | perplexity 118.89
# | epoch 3 |  iter 1061 / 1327 | time 3830[s] | perplexity 103.53
# | epoch 3 |  iter 1081 / 1327 | time 3833[s] | perplexity 89.93
# | epoch 3 |  iter 1101 / 1327 | time 3836[s] | perplexity 96.33
# | epoch 3 |  iter 1121 / 1327 | time 3839[s] | perplexity 122.47
# | epoch 3 |  iter 1141 / 1327 | time 3842[s] | perplexity 115.99
# | epoch 3 |  iter 1161 / 1327 | time 3845[s] | perplexity 107.25
# | epoch 3 |  iter 1181 / 1327 | time 3848[s] | perplexity 110.75
# | epoch 3 |  iter 1201 / 1327 | time 3851[s] | perplexity 93.74
# | epoch 3 |  iter 1221 / 1327 | time 3854[s] | perplexity 89.49
# | epoch 3 |  iter 1241 / 1327 | time 3857[s] | perplexity 106.30
# | epoch 3 |  iter 1261 / 1327 | time 3860[s] | perplexity 105.26
# | epoch 3 |  iter 1281 / 1327 | time 3863[s] | perplexity 101.53
# | epoch 3 |  iter 1301 / 1327 | time 3866[s] | perplexity 130.37
# | epoch 3 |  iter 1321 / 1327 | time 3869[s] | perplexity 126.41
# | epoch 4 |  iter 1 / 1327 | time 3871[s] | perplexity 134.48
# | epoch 4 |  iter 21 / 1327 | time 3874[s] | perplexity 121.90
# | epoch 4 |  iter 41 / 1327 | time 3877[s] | perplexity 107.50
# | epoch 4 |  iter 61 / 1327 | time 3880[s] | perplexity 107.32
# | epoch 4 |  iter 81 / 1327 | time 3883[s] | perplexity 97.06
# | epoch 4 |  iter 101 / 1327 | time 3886[s] | perplexity 86.97
# | epoch 4 |  iter 121 / 1327 | time 3889[s] | perplexity 96.79
# | epoch 4 |  iter 141 / 1327 | time 3892[s] | perplexity 103.82
# | epoch 4 |  iter 161 / 1327 | time 3895[s] | perplexity 117.36
# | epoch 4 |  iter 181 / 1327 | time 3898[s] | perplexity 129.38
# | epoch 4 |  iter 201 / 1327 | time 3901[s] | perplexity 120.23
# | epoch 4 |  iter 221 / 1327 | time 3904[s] | perplexity 122.98
# | epoch 4 |  iter 241 / 1327 | time 3907[s] | perplexity 115.06
# | epoch 4 |  iter 261 / 1327 | time 3910[s] | perplexity 116.31
# | epoch 4 |  iter 281 / 1327 | time 3913[s] | perplexity 122.55
# | epoch 4 |  iter 301 / 1327 | time 3916[s] | perplexity 103.56
# | epoch 4 |  iter 321 / 1327 | time 3919[s] | perplexity 85.26
# | epoch 4 |  iter 341 / 1327 | time 3922[s] | perplexity 100.84
# | epoch 4 |  iter 361 / 1327 | time 3925[s] | perplexity 130.04
# | epoch 4 |  iter 381 / 1327 | time 3928[s] | perplexity 98.46
# | epoch 4 |  iter 401 / 1327 | time 3931[s] | perplexity 109.89
# | epoch 4 |  iter 421 / 1327 | time 3935[s] | perplexity 94.42
# | epoch 4 |  iter 441 / 1327 | time 3938[s] | perplexity 104.65
# | epoch 4 |  iter 461 / 1327 | time 3941[s] | perplexity 99.55
# | epoch 4 |  iter 481 / 1327 | time 3944[s] | perplexity 103.22
# | epoch 4 |  iter 501 / 1327 | time 3947[s] | perplexity 109.53
# | epoch 4 |  iter 521 / 1327 | time 3950[s] | perplexity 118.22
# | epoch 4 |  iter 541 / 1327 | time 3953[s] | perplexity 112.17
# | epoch 4 |  iter 561 / 1327 | time 3956[s] | perplexity 103.97
# | epoch 4 |  iter 581 / 1327 | time 3959[s] | perplexity 90.18
# | epoch 4 |  iter 601 / 1327 | time 3962[s] | perplexity 126.87
# | epoch 4 |  iter 621 / 1327 | time 3965[s] | perplexity 120.89
# | epoch 4 |  iter 641 / 1327 | time 3968[s] | perplexity 111.20
# | epoch 4 |  iter 661 / 1327 | time 3971[s] | perplexity 104.29
# | epoch 4 |  iter 681 / 1327 | time 3974[s] | perplexity 85.82
# | epoch 4 |  iter 701 / 1327 | time 3977[s] | perplexity 103.03
# | epoch 4 |  iter 721 / 1327 | time 3980[s] | perplexity 108.39
# | epoch 4 |  iter 741 / 1327 | time 3983[s] | perplexity 95.75
# | epoch 4 |  iter 761 / 1327 | time 3986[s] | perplexity 89.19
# | epoch 4 |  iter 781 / 1327 | time 3989[s] | perplexity 88.40
# | epoch 4 |  iter 801 / 1327 | time 3992[s] | perplexity 98.39
# | epoch 4 |  iter 821 / 1327 | time 3995[s] | perplexity 103.01
# | epoch 4 |  iter 841 / 1327 | time 3998[s] | perplexity 98.19
# | epoch 4 |  iter 861 / 1327 | time 4001[s] | perplexity 103.83
# | epoch 4 |  iter 881 / 1327 | time 4005[s] | perplexity 92.53
# | epoch 4 |  iter 901 / 1327 | time 4008[s] | perplexity 116.56
# | epoch 4 |  iter 921 / 1327 | time 4011[s] | perplexity 102.74
# | epoch 4 |  iter 941 / 1327 | time 4014[s] | perplexity 112.28
# | epoch 4 |  iter 961 / 1327 | time 4017[s] | perplexity 112.86
# | epoch 4 |  iter 981 / 1327 | time 4020[s] | perplexity 106.61
# | epoch 4 |  iter 1001 / 1327 | time 4023[s] | perplexity 97.17
# | epoch 4 |  iter 1021 / 1327 | time 4026[s] | perplexity 113.00
# | epoch 4 |  iter 1041 / 1327 | time 4029[s] | perplexity 103.79
# | epoch 4 |  iter 1061 / 1327 | time 4032[s] | perplexity 89.30
# | epoch 4 |  iter 1081 / 1327 | time 4035[s] | perplexity 79.85
# | epoch 4 |  iter 1101 / 1327 | time 4038[s] | perplexity 80.10
# | epoch 4 |  iter 1121 / 1327 | time 4041[s] | perplexity 103.38
# | epoch 4 |  iter 1141 / 1327 | time 4044[s] | perplexity 100.62
# | epoch 4 |  iter 1161 / 1327 | time 4047[s] | perplexity 91.99
# | epoch 4 |  iter 1181 / 1327 | time 4050[s] | perplexity 96.75
# | epoch 4 |  iter 1201 / 1327 | time 4053[s] | perplexity 82.98
# | epoch 4 |  iter 1221 / 1327 | time 4056[s] | perplexity 76.40
# | epoch 4 |  iter 1241 / 1327 | time 4060[s] | perplexity 91.72
# | epoch 4 |  iter 1261 / 1327 | time 4063[s] | perplexity 93.68
# | epoch 4 |  iter 1281 / 1327 | time 4067[s] | perplexity 89.96
# | epoch 4 |  iter 1301 / 1327 | time 4070[s] | perplexity 112.05
# | epoch 4 |  iter 1321 / 1327 | time 4073[s] | perplexity 110.73
# evaluating perplexity ...
# 234 / 235
# test perplexity:  135.6453823019676
